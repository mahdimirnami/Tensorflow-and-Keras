# %% [markdown]
# <a href="https://colab.research.google.com/github/mahdimirnami/Tensorflow-and-Keras/blob/main/california_housing_subclassingAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **import library data california**

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # **Convert to Object**

# %%
housing = fetch_california_housing()

# %% [markdown]
# # **train and test Model**

# %%
X_train_full , X_test , Y_train_full , Y_test = train_test_split(housing.data,housing.target)
X_train ,X_valid , Y_train , Y_valid = train_test_split(X_train_full , Y_train_full)

# %% [markdown]
# # **Classifier with Keras**

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %% [markdown]
# # **model concatenate with one input and one output**

# %%
              #       ┌─────────────┐
              #       │   input_    │  (۸ فیچر خام)
              #       └──────┬──────┘
              #       │              │
              # (مسیر Wide)    (مسیر Deep)
              #       │              │
              #       │        ┌─────▼─────┐
              #       │        │  hidden1  │ (۳۰ نورون)
              #       │        └─────┬─────┘
              #       │              │
              #       │        ┌─────▼─────┐
              #       │        │  hidden2  │ (۳۰ نورون)
              #       │        └─────┬─────┘
              #       │              │
              #       └──────┬───────┘
              #       ┌───────▼───────┐
              #       │    concat     │ (۳۸ = ۸+۳۰)
              #       └───────┬───────┘
              #       ┌───────▼───────┐
              #       │    output     │ (۱ نورون، خروجی نهایی)
              #       └───────────────┘

# %%
from tensorflow import keras

input_ = keras.layers.Input(shape=X_train.shape[1:])
hidden1 = keras.layers.Dense(30, activation='relu')(input_)
hidden2 = keras.layers.Dense(30, activation='relu')(hidden1)
concat = keras.layers.Concatenate()([input_, hidden2])
output = keras.layers.Dense(1)(concat)

model = keras.Model(inputs=[input_], outputs=[output])

# %%
model.compile(loss="mean_squared_error", optimizer="sgd")

history = model.fit(X_train, Y_train, epochs=20,
                     validation_data=(X_valid, Y_valid))

mse_test = model.evaluate(X_test, Y_test)
print("MSE روی داده تست:", mse_test)

X_new = X_test[:3]
Y_pred = model.predict(X_new)
print("پیش‌بینی‌ها:", Y_pred)
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.4226 - val_loss: 56.9540
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: nan - val_loss: nan
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan - val_loss: nan
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan - val_loss: nan
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan - val_loss: nan
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: nan - val_loss: nan
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan - val_loss: nan
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: nan - val_loss: nan
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan - val_loss: nan
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: nan - val_loss: nan
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: nan - val_loss: nan
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# MSE روی داده تست: nan
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# پیش‌بینی‌ها: [[nan]
#  [nan]
#  [nan]]

# %% [markdown]
# # **model concatenate with two input and one output**

# %%
# ┌──────────────────┐              ┌──────────────────┐
# │     input_A       │              │     input_B       │
# │  (wide_input)      │              │  (deep_input)      │
# │    ۵ فیچر          │              │    ۶ فیچر          │
# └─────────┬─────────┘              └─────────┬─────────┘
#           │                                  │
#           │                            ┌─────▼─────┐
#           │                            │  hidden1  │
#           │                            │ (۳۰ نورون) │
#           │                            └─────┬─────┘
#           │                                  │
#           │                            ┌─────▼─────┐
#           │                            │  hidden2  │
#           │                            │ (۳۰ نورون) │
#           │                            └─────┬─────┘
#           │                                  │
#           └────────────────┬─────────────────┘
#                     ┌───────▼───────┐
#                     │     concat     │
#                     │ (۵ + ۳۰ = ۳۵)  │
#                     └───────┬───────┘
#                     ┌───────▼───────┐
#                     │     output     │
#                     │   (۱ نورون)     │
#                     └───────────────┘

# %%
from tensorflow import keras

class WideAndDeepModel(keras.Model):
    def __init__(self, units=30, activation="relu", **kwargs):
        super().__init__(**kwargs)
        self.hidden1 = keras.layers.Dense(units, activation=activation)
        self.hidden2 = keras.layers.Dense(units, activation=activation)
        self.main_output = keras.layers.Dense(1)

    def call(self, inputs):
        input_A, input_B = inputs
        hidden1 = self.hidden1(input_B)
        hidden2 = self.hidden2(hidden1)
        concat = keras.layers.Concatenate()([input_A, hidden2])
        main_output = self.main_output(concat)
        return main_output

model = WideAndDeepModel()

# %% [markdown]
# # **divide data for two inputs**

# %%
model.compile(loss="mse", optimizer=keras.optimizers.SGD(learning_rate=1e-3))

X_train_A, X_train_B = X_train[:, :5], X_train[:, 2:]
X_valid_A, X_valid_B = X_valid[:, :5], X_valid[:, 2:]
X_test_A, X_test_B = X_test[:, :5], X_test[:, 2:]
X_new_A, X_new_B = X_test_A[:3], X_test_B[:3]

history = model.fit((X_train_A, X_train_B), Y_train, epochs=20,
                     validation_data=((X_valid_A, X_valid_B), Y_valid))
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.3674 - val_loss: 1.0338
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8445 - val_loss: 0.7591
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6918 - val_loss: 0.6699
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6280 - val_loss: 0.6232
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5902 - val_loss: 0.5931
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.5635 - val_loss: 0.5692
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.5453 - val_loss: 0.5544
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5309 - val_loss: 0.5419
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5201 - val_loss: 0.5316
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.5110 - val_loss: 0.5241
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.5035 - val_loss: 0.5163
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4972 - val_loss: 0.5121
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4918 - val_loss: 0.5050
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4870 - val_loss: 0.5001
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4825 - val_loss: 0.4956
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4772 - val_loss: 0.4905
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4736 - val_loss: 0.4882
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4697 - val_loss: 0.4851
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4661 - val_loss: 0.4801
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4626 - val_loss: 0.4801

# %%
mse_test = model.evaluate((X_test_A,X_test_B),Y_test)
Y_pred = model.predict((X_new_A,X_new_B))
print("پیش‌بینی‌ها:", Y_pred)
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4980
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# پیش‌بینی‌ها: [[2.646073 ]
#  [1.8110425]
#  [1.2666221]]

# %% [markdown]
# # **model concatenate with two input and one output**

# %%
# ┌──────────────────┐              ┌──────────────────┐
# │     input_A       │              │     input_B       │
# │  (wide_input)      │              │  (deep_input)      │
# │    ۵ فیچر          │              │    ۶ فیچر          │
# └─────────┬─────────┘              └─────────┬─────────┘
#           │                                  │
#           │                            ┌─────▼─────┐
#           │                            │  hidden1  │
#           │                            │ (۳۰ نورون) │
#           │                            └─────┬─────┘
#           │                                  │
#           │                            ┌─────▼─────┐
#           │                            │  hidden2  │
#           │                            │ (۳۰ نورون) │
#           │                            └──┬─────┬───┘
#           │                               │     │
#           │                               │     └──────────────┐
#           └────────────────┬──────────────┘                    │
#                     ┌───────▼───────┐                   ┌───────▼───────┐
#                     │     concat     │                   │  aux_output   │
#                     │  (۵+۳۰ = ۳۵)   │                   │   (۱ نورون)    │
#                     └───────┬───────┘                   └───────────────┘
#                     ┌───────▼───────┐                     خروجی کمکی
#                     │     output     │                   (مستقیم از hidden2)
#                     │   (۱ نورون)     │
#                     └───────────────┘
#                      خروجی اصلی

# %%
from tensorflow import keras

input_A = keras.layers.Input(shape=[5], name="wide_input")
input_B = keras.layers.Input(shape=[6], name="deep_input")
hidden1 = keras.layers.Dense(30, activation='relu')(input_B)
hidden2 = keras.layers.Dense(30, activation='relu')(hidden1)
concat = keras.layers.concatenate([input_A, hidden2])
output = keras.layers.Dense(1, name="output")(concat)
aux_output = keras.layers.Dense(1,name="aux_output")(hidden2)


model = keras.Model(inputs=[input_A, input_B], outputs=[output , aux_output])

# %% [markdown]
# # **divide data for two inputs and two output**

# %%
model.compile(loss=["mse" ,"mse"], loss_weights=[0.9,0.1] , optimizer=keras.optimizers.SGD(learning_rate=1e-3))

X_train_A,X_train_B = X_train[:,:5],X_train[:,2:]
X_valid_A,X_valid_B = X_valid[:,:5],X_valid[:,2:]
X_test_A,X_test_B = X_test[:,:5],X_test[:,2:]
X_new_A, X_new_B = X_test_A[:3], X_test_B[:3]

# checkpoint =>  متد کالبک برای ذخیره بهترین بهترین عملکرد
checkpoint_cb = keras.callbacks.ModelCheckpoint("my_keras_model.keras", save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=10,restore_best_weights=True)
history= model.fit(
    [X_train_A,X_train_B ], [Y_train , Y_train] , epochs=20
    , validation_data=([X_valid_A,X_valid_B],[Y_valid , Y_valid]),callbacks=[checkpoint_cb , early_stopping_cb]
    )
model = keras.models.load_model('my_keras_model.keras')
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - aux_output_loss: 5.9127 - loss: 2.2212 - output_loss: 1.8103 - val_aux_output_loss: 4.4457 - val_loss: 1.2126 - val_output_loss: 0.8531
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - aux_output_loss: 3.4603 - loss: 1.0229 - output_loss: 0.7523 - val_aux_output_loss: 2.6386 - val_loss: 0.9074 - val_output_loss: 0.7149
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_output_loss: 2.2018 - loss: 0.8208 - output_loss: 0.6673 - val_aux_output_loss: 1.8499 - val_loss: 0.7761 - val_output_loss: 0.6566
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_output_loss: 1.6643 - loss: 0.7256 - output_loss: 0.6213 - val_aux_output_loss: 1.5161 - val_loss: 0.7083 - val_output_loss: 0.6184
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_output_loss: 1.4364 - loss: 0.6745 - output_loss: 0.5897 - val_aux_output_loss: 1.3757 - val_loss: 0.6697 - val_output_loss: 0.5911
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_output_loss: 1.3260 - loss: 0.6416 - output_loss: 0.5658 - val_aux_output_loss: 1.3037 - val_loss: 0.6418 - val_output_loss: 0.5682
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_output_loss: 1.2607 - loss: 0.6169 - output_loss: 0.5454 - val_aux_output_loss: 1.2567 - val_loss: 0.6199 - val_output_loss: 0.5490
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_output_loss: 1.2151 - loss: 0.5979 - output_loss: 0.5291 - val_aux_output_loss: 1.2201 - val_loss: 0.6032 - val_output_loss: 0.5345
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_output_loss: 1.1799 - loss: 0.5823 - output_loss: 0.5158 - val_aux_output_loss: 1.1899 - val_loss: 0.5885 - val_output_loss: 0.5215
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_output_loss: 1.1506 - loss: 0.5694 - output_loss: 0.5048 - val_aux_output_loss: 1.1634 - val_loss: 0.5766 - val_output_loss: 0.5113
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_output_loss: 1.1241 - loss: 0.5590 - output_loss: 0.4962 - val_aux_output_loss: 1.1373 - val_loss: 0.5672 - val_output_loss: 0.5038
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - aux_output_loss: 1.0997 - loss: 0.5496 - output_loss: 0.4884 - val_aux_output_loss: 1.1146 - val_loss: 0.5580 - val_output_loss: 0.4960
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - aux_output_loss: 1.0777 - loss: 0.5426 - output_loss: 0.4835 - val_aux_output_loss: 1.0923 - val_loss: 0.5508 - val_output_loss: 0.4905
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_output_loss: 1.0565 - loss: 0.5351 - output_loss: 0.4771 - val_aux_output_loss: 1.0707 - val_loss: 0.5430 - val_output_loss: 0.4843
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_output_loss: 1.0366 - loss: 0.5286 - output_loss: 0.4723 - val_aux_output_loss: 1.0517 - val_loss: 0.5387 - val_output_loss: 0.4816
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_output_loss: 1.0176 - loss: 0.5226 - output_loss: 0.4675 - val_aux_output_loss: 1.0328 - val_loss: 0.5311 - val_output_loss: 0.4752
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_output_loss: 0.9997 - loss: 0.5171 - output_loss: 0.4635 - val_aux_output_loss: 1.0150 - val_loss: 0.5270 - val_output_loss: 0.4726
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_output_loss: 0.9826 - loss: 0.5118 - output_loss: 0.4595 - val_aux_output_loss: 0.9963 - val_loss: 0.5209 - val_output_loss: 0.4679
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_output_loss: 0.9652 - loss: 0.5071 - output_loss: 0.4561 - val_aux_output_loss: 0.9802 - val_loss: 0.5159 - val_output_loss: 0.4643
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_output_loss: 0.9488 - loss: 0.5022 - output_loss: 0.4525 - val_aux_output_loss: 0.9630 - val_loss: 0.5116 - val_output_loss: 0.4614

# %% [markdown]
# # **Model Evaluation**

# %%
total_loss,main_loss,aux_loss = model.evaluate(
    [X_test_A,X_test_B],[Y_test,Y_test]
)
Y_pred_main , Y_pred_aux = model.predict([X_new_A,X_new_B])
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - aux_output_loss: 1.0137 - loss: 0.5416 - output_loss: 0.4880
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7dfd64fb3d80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
